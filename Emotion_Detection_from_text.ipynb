# %%
# %cd /content/drive/MyDrive/MLProjects/Emotion_Detection_from_text

import pandas as pd
import joblib
# import spacy
import sklearn

df = pd.read_csv("Emotion_classify_Data.csv")
df.head()
# Out:
# /content/drive/MyDrive/MLProjects/Emotion_Detection_from_text
#                                              Comment Emotion
# 0  i seriously hate one subject to death but now ...    fear
# 1                 im so full of life i feel appalled   anger
# 2  i sit here to write i start to dig out my feel...    fear
# 3  ive been really angry with r and i feel like a...     joy
# 4  i feel suspicious if there is no one outside l...    fear

# %%
df["Emotion"].value_counts()
# Out:
# Emotion
# anger    2000
# joy      2000
# fear     1937
# Name: count, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

encoder= LabelEncoder()

y = encoder.fit_transform(df["Emotion"])
y
# Out:
# array([1, 0, 1, ..., 2, 1, 0])

# %%
encoder.classes_
# Out:
# array(['anger', 'fear', 'joy'], dtype=object)

# %%
labels = {l:i for i,l in enumerate(encoder.classes_)}
labels
# Out:
# {'anger': 0, 'fear': 1, 'joy': 2}

# %%
df["labeled_taget"] = y
df.head()
# Out:
#                                              Comment Emotion  \
# 0  i seriously hate one subject to death but now ...    fear
# 1                 im so full of life i feel appalled   anger
# 2  i sit here to write i start to dig out my feel...    fear
# 3  ive been really angry with r and i feel like a...     joy
# 4  i feel suspicious if there is no one outside l...    fear
#
#   processed_comment  labeled_taget
# 0              None              1
# 1              None              0
# 2              None              1
# 3              None              2
# 4              None              1

# %%
from sklearn.model_selection import train_test_split

x_train,x_test, y_train,y_test = train_test_split(df["Comment"], df["labeled_taget"],
                                                  test_size = 0.25,
                                                  stratify = df['labeled_taget'],
                                                  random_state = 2)

print(x_train.shape, x_test.shape)
# Out:
# (4452,) (1485,)

# %%
y_train.value_counts()
# Out:
# labeled_taget
# 0    1500
# 2    1500
# 1    1452
# Name: count, dtype: int64

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.pipeline import Pipeline

from sklearn.naive_bayes import MultinomialNB
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV


models = [
    {
        "name": "logistic_regression",
        "model": LogisticRegression(max_iter = 10000),
        "params":{
            "logistic_regression__C": [1,0.1,0.01]
        }

    },

    {
        "name": "random_forest",
        "model": RandomForestClassifier(),
        "params":{
            "random_forest__n_estimators" : [100,150,250]
        }
    },

    {
        "name": "knn",
        "model": KNeighborsClassifier(),
        "params":{
            "knn__n_neighbors" : [10, 20, 40]

        }
    },

     {
        "name": "naive_bayes",
        "model": MultinomialNB(),
        "params":{}

    }




]

# %%
results = {}
best_models ={}
for obj in models:
  name= obj["name"]
  model = obj["model"]
  params = obj["params"]
  pipe = Pipeline([
      ("vectorizer", TfidfVectorizer()),
      (name, model)
  ])

  clf = GridSearchCV(pipe, params, cv=5)
  clf.fit(x_train,y_train)
  results[name] = {"best_score":clf.best_score_, "best_params": clf.best_params_}
  best_models[name] = clf.best_estimator_
  print(clf.cv_results_)
# Out:
# {'mean_fit_time': array([1.13851533, 0.54922147, 0.26865358]), 'std_fit_time': array([0.36988439, 0.17437718, 0.0837905 ]), 'mean_score_time': array([0.08431978, 0.05951347, 0.0593255 ]), 'std_score_time': array([0.031696  , 0.01657442, 0.0192481 ]), 'param_logistic_regression__C': masked_array(data=[1, 0.1, 0.01],
#              mask=[False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'logistic_regression__C': 1}, {'logistic_regression__C': 0.1}, {'logistic_regression__C': 0.01}], 'split0_test_score': array([0.88664422, 0.79461279, 0.68574635]), 'split1_test_score': array([0.90572391, 0.78563412, 0.66666667]), 'split2_test_score': array([0.9011236 , 0.81460674, 0.6988764 ]), 'split3_test_score': array([0.89775281, 0.79662921, 0.69662921]), 'split4_test_score': array([0.89213483, 0.80786517, 0.69101124]), 'mean_test_score': array([0.89667587, 0.79986961, 0.68778597]), 'std_test_score': array([0.00669424, 0.01021661, 0.01150468]), 'rank_test_score': array([1, 2, 3], dtype=int32)}
# {'mean_fit_time': array([3.64269357, 4.87523837, 8.03881478]), 'std_fit_time': array([0.46326832, 0.5243565 , 0.78393815]), 'mean_score_time': array([0.09200149, 0.11034412, 0.15724936]), 'std_score_time': array([0.01650055, 0.01529737, 0.00280846]), 'param_random_forest__n_estimators': masked_array(data=[100, 150, 250],
#              mask=[False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'random_forest__n_estimators': 100}, {'random_forest__n_estimators': 150}, {'random_forest__n_estimators': 250}], 'split0_test_score': array([0.90460157, 0.8956229 , 0.90460157]), 'split1_test_score': array([0.8989899 , 0.90572391, 0.8989899 ]), 'split2_test_score': array([0.90674157, 0.90786517, 0.91573034]), 'split3_test_score': array([0.88314607, 0.88426966, 0.89325843]), 'split4_test_score': array([0.88651685, 0.8988764 , 0.89550562]), 'mean_test_score': array([0.89599919, 0.89847161, 0.90161717]), 'std_test_score': array([0.00952325, 0.00837626, 0.00802758]), 'rank_test_score': array([3, 2, 1], dtype=int32)}
# {'mean_fit_time': array([0.08767319, 0.15031629, 0.09120235]), 'std_fit_time': array([0.00451398, 0.07069826, 0.00526475]), 'mean_score_time': array([1.21506648, 1.62825851, 1.21000686]), 'std_score_time': array([0.04779197, 0.34418069, 0.02425287]), 'param_knn__n_neighbors': masked_array(data=[10, 20, 40],
#              mask=[False, False, False],
#        fill_value='?',
#             dtype=object), 'params': [{'knn__n_neighbors': 10}, {'knn__n_neighbors': 20}, {'knn__n_neighbors': 40}], 'split0_test_score': array([0.74074074, 0.77216611, 0.78675645]), 'split1_test_score': array([0.74635241, 0.76094276, 0.77890011]), 'split2_test_score': array([0.75617978, 0.78089888, 0.80224719]), 'split3_test_score': array([0.78089888, 0.79325843, 0.79550562]), 'split4_test_score': array([0.73932584, 0.78426966, 0.79325843]), 'mean_test_score': array([0.75269953, 0.77830717, 0.79133356]), 'std_test_score': array([0.01529359, 0.0110004 , 0.00794681]), 'rank_test_score': array([3, 2, 1], dtype=int32)}
# {'mean_fit_time': array([0.10297017]), 'std_fit_time': array([0.02150949]), 'mean_score_time': array([0.02397175]), 'std_score_time': array([0.00662179]), 'params': [{}], 'split0_test_score': array([0.88327722]), 'split1_test_score': array([0.87654321]), 'split2_test_score': array([0.89325843]), 'split3_test_score': array([0.88426966]), 'split4_test_score': array([0.87078652]), 'mean_test_score': array([0.88162701]), 'std_test_score': array([0.00759418]), 'rank_test_score': array([1], dtype=int32)}

# %%
results = pd.DataFrame(results)
results
# Out:
#                        logistic_regression  \
# best_score                        0.896676
# best_params  {'logistic_regression__C': 1}
#
#                                     random_forest                       knn  \
# best_score                               0.901617                  0.791334
# best_params  {'random_forest__n_estimators': 250}  {'knn__n_neighbors': 40}
#
#             naive_bayes
# best_score     0.881627
# best_params          {}

# %%
from sklearn.metrics import classification_report
for name,model in best_models.items():
  y_pred = model.predict(x_test)
  print(name)
  print(classification_report(y_test, y_pred))
# Out:
# logistic_regression
#               precision    recall  f1-score   support
#
#            0       0.91      0.91      0.91       500
#            1       0.94      0.88      0.91       485
#            2       0.89      0.95      0.92       500
#
#     accuracy                           0.91      1485
#    macro avg       0.91      0.91      0.91      1485
# weighted avg       0.91      0.91      0.91      1485
#
# random_forest
#               precision    recall  f1-score   support
#
#            0       0.95      0.89      0.92       500
#            1       0.93      0.92      0.93       485
#            2       0.89      0.96      0.92       500
#
#     accuracy                           0.92      1485
#    macro avg       0.92      0.92      0.92      1485
# weighted avg       0.92      0.92      0.92      1485
#
# knn
#               precision    recall  f1-score   support
#
#            0       0.76      0.87      0.81       500
#            1       0.80      0.81      0.81       485
#            2       0.86      0.72      0.79       500
#
#     accuracy                           0.80      1485
#    macro avg       0.81      0.80      0.80      1485
# weighted avg       0.81      0.80      0.80      1485
#
# naive_bayes
#               precision    recall  f1-score   support
#
#            0       0.87      0.92      0.89       500
#            1       0.92      0.87      0.90       485
#            2       0.92      0.91      0.92       500
#
#     accuracy                           0.90      1485
#    macro avg       0.90      0.90      0.90      1485
# weighted avg       0.90      0.90      0.90      1485

# %%
import spacy

nlp = spacy.load("en_core_web_sm")

def preprocess(text):
  doc =  nlp(text)
  result = []

  for token in doc:
    if token.is_punct or token.is_stop:
      continue

    result.append(token.lemma_)

  return " ".join(result)

# %%
df["processed_comment"] = df["Comment"].apply(preprocess)

# %%
df.to_csv("processed_dataset.csv", index = False)

# %%
df.head()
# Out:
#                                              Comment Emotion  \
# 0  i seriously hate one subject to death but now ...    fear
# 1                 im so full of life i feel appalled   anger
# 2  i sit here to write i start to dig out my feel...    fear
# 3  ive been really angry with r and i feel like a...     joy
# 4  i feel suspicious if there is no one outside l...    fear
#
#                                    processed_comment  labeled_taget
# 0   seriously hate subject death feel reluctant drop              1
# 1                               m life feel appalled              0
# 2  sit write start dig feeling think afraid accep...              1
# 3             ve angry r feel like idiot trust place              2
# 4        feel suspicious outside like rapture happen              1

# %%
from sklearn.model_selection import train_test_split

x_train,x_test, y_train,y_test = train_test_split(df["processed_comment"], df["labeled_taget"],
                                                  test_size = 0.25,
                                                  stratify = df['labeled_taget'],
                                                  random_state = 2)

# %%
results = {}
best_models ={}
cv_results =[]
for obj in models:
  name= obj["name"]
  model = obj["model"]
  params = obj["params"]
  pipe = Pipeline([
      ("vectorizer", TfidfVectorizer()),
      (name, model)
  ])

  clf = GridSearchCV(pipe, params, cv=5)
  clf.fit(x_train,y_train)
  results[name] = {"best_score":clf.best_score_, "best_params": clf.best_params_}
  best_models[name] = clf.best_estimator_
  cv_results.append(clf.cv_results_)

# %%
from sklearn.metrics import classification_report
for name,model in best_models.items():
  y_pred = model.predict(x_test)
  print(name)
  print(classification_report(y_test, y_pred))
# Out:
# logistic_regression
#               precision    recall  f1-score   support
#
#            0       0.92      0.91      0.91       500
#            1       0.95      0.89      0.92       485
#            2       0.90      0.96      0.93       500
#
#     accuracy                           0.92      1485
#    macro avg       0.92      0.92      0.92      1485
# weighted avg       0.92      0.92      0.92      1485
#
# random_forest
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92       500
#            1       0.94      0.92      0.93       485
#            2       0.91      0.95      0.93       500
#
#     accuracy                           0.93      1485
#    macro avg       0.93      0.93      0.93      1485
# weighted avg       0.93      0.93      0.93      1485
#
# knn
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86       500
#            1       0.84      0.88      0.86       485
#            2       0.94      0.80      0.86       500
#
#     accuracy                           0.86      1485
#    macro avg       0.87      0.86      0.86      1485
# weighted avg       0.87      0.86      0.86      1485
#
# naive_bayes
#               precision    recall  f1-score   support
#
#            0       0.89      0.91      0.90       500
#            1       0.91      0.89      0.90       485
#            2       0.92      0.91      0.91       500
#
#     accuracy                           0.91      1485
#    macro avg       0.91      0.90      0.91      1485
# weighted avg       0.91      0.91      0.91      1485

# %%
rdf = pd.DataFrame({})
for item in cv_results:
  x = pd.DataFrame(item)
  rdf = pd.concat([rdf,x], axis=0)



rdf
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.680657      0.092821         0.040916        0.005558
# 1       0.311978      0.049370         0.034642        0.008196
# 2       0.221620      0.112047         0.019485        0.001841
# 0       2.726078      1.108227         0.077553        0.002353
# 1       5.064076      1.458428         0.117204        0.017949
# 2       8.220712      2.721538         0.200672        0.029082
# 0       0.070194      0.031699         0.490948        0.025978
# 1       0.071949      0.017339         0.592924        0.089563
# 2       0.104893      0.025200         0.640934        0.059425
# 0       0.052044      0.001744         0.011632        0.000290
#
#   param_logistic_regression__C                                params  \
# 0                            1         {'logistic_regression__C': 1}
# 1                          0.1       {'logistic_regression__C': 0.1}
# 2                         0.01      {'logistic_regression__C': 0.01}
# 0                          NaN  {'random_forest__n_estimators': 100}
# 1                          NaN  {'random_forest__n_estimators': 150}
# 2                          NaN  {'random_forest__n_estimators': 250}
# 0                          NaN              {'knn__n_neighbors': 10}
# 1                          NaN              {'knn__n_neighbors': 20}
# 2                          NaN              {'knn__n_neighbors': 40}
# 0                          NaN                                    {}
#
#    split0_test_score  split1_test_score  split2_test_score  split3_test_score  \
# 0           0.914703           0.927048           0.917978           0.907865
# 1           0.872054           0.881033           0.883146           0.869663
# 2           0.776655           0.780022           0.792135           0.791011
# 0           0.921437           0.918070           0.922472           0.915730
# 1           0.923681           0.922559           0.921348           0.913483
# 2           0.919192           0.929293           0.925843           0.913483
# 0           0.836139           0.832772           0.850562           0.849438
# 1           0.855219           0.845118           0.847191           0.838202
# 2           0.859708           0.855219           0.839326           0.828090
# 0           0.898990           0.882155           0.895506           0.888764
#
#    split4_test_score  mean_test_score  std_test_score  rank_test_score  \
# 0           0.913483         0.916215        0.006324                1
# 1           0.869663         0.875112        0.005802                2
# 2           0.776404         0.783246        0.006927                3
# 0           0.904494         0.916441        0.006437                2
# 1           0.897753         0.915765        0.009692                3
# 2           0.905618         0.918686        0.008507                1
# 0           0.834831         0.840749        0.007638                3
# 1           0.843820         0.845910        0.005526                1
# 2           0.839326         0.844334        0.011566                2
# 0           0.891011         0.891285        0.005779                1
#
#   param_random_forest__n_estimators param_knn__n_neighbors
# 0                               NaN                    NaN
# 1                               NaN                    NaN
# 2                               NaN                    NaN
# 0                               100                    NaN
# 1                               150                    NaN
# 2                               250                    NaN
# 0                               NaN                     10
# 1                               NaN                     20
# 2                               NaN                     40
# 0                               NaN                    NaN

# %%
# import json


# with open("emotion_labels.json","w") as f:
#   f.write(json.dumps(labels))

# %%
joblib.dump(best_models["random_forest"], "emotion_detection_model.pkl")
# Out:
# ['emotion_detection_model.pkl']

# %%
import spacy
